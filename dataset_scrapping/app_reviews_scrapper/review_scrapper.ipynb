# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: pandas in a:\conda\envs\tf2161\lib\site-packages (from -r requirements.txt (line 1)) (2.2.3)
# Requirement already satisfied: openpyxl in a:\conda\envs\tf2161\lib\site-packages (from -r requirements.txt (line 2)) (3.1.5)
# Requirement already satisfied: requests in a:\conda\envs\tf2161\lib\site-packages (from -r requirements.txt (line 3)) (2.32.3)
# Requirement already satisfied: numpy>=1.26.0 in a:\conda\envs\tf2161\lib\site-packages (from pandas->-r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in a:\conda\envs\tf2161\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in a:\conda\envs\tf2161\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in a:\conda\envs\tf2161\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: et-xmlfile in a:\conda\envs\tf2161\lib\site-packages (from openpyxl->-r requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in a:\conda\envs\tf2161\lib\site-packages (from requests->-r requirements.txt (line 3)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in a:\conda\envs\tf2161\lib\site-packages (from requests->-r requirements.txt (line 3)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in a:\conda\envs\tf2161\lib\site-packages (from requests->-r requirements.txt (line 3)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in a:\conda\envs\tf2161\lib\site-packages (from requests->-r requirements.txt (line 3)) (2024.12.14)
# Requirement already satisfied: six>=1.5 in a:\conda\envs\tf2161\lib\site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 1)) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import time
import requests
from datetime import datetime, timedelta
from pathlib import Path
import requests
import json
import os
import pandas as pd

# %%
# Load app IDs from file
app_ids = []
with open("app_ids_with_reviews.txt", "r") as f:
    app_ids = [line.strip() for line in f]

# API parameters
base_url = "https://store.steampowered.com/appreviews/"
time_interval = timedelta(hours=24)
end_time = datetime.now()
start_time = datetime(2024, 1, 1, 0, 0, 0)  # Adjust if needed

print(f"Start time: {start_time}")
print(f"End time: {end_time}")
print(start_time.timestamp(), end_time.timestamp())


selected_reviews = []

session = requests.Session()
session.mount("https://", requests.adapters.HTTPAdapter(max_retries=3))

def get_user_reviews(app_id, params, max_retries=3):
    """Fetches reviews from Steam API with retry on timeout."""
    for attempt in range(max_retries):
        try:
            response = session.get(f"{base_url}{app_id}", params=params, timeout=10, verify=True)
            response.raise_for_status()
            return response.json()
        except requests.exceptions.Timeout:
            print(f"Timeout for app {app_id}. Retrying in 10 seconds... (Attempt {attempt + 1}/{max_retries})")
            time.sleep(10)
        except requests.exceptions.RequestException as e:
            print(f"Request failed for app {app_id}: {e}")
            return None  # Stop retrying on non-timeout errors
    return None  # If all retries fail



# # Process each app ID
# for app_id in app_ids:
#     print(f"\nGetting reviews for app_id: {app_id}")
#     params = {
#         "json": 1,
#         "language": "turkish",
#         "cursor": "*",
#         "num_per_page": 100,
#         "filter": "recent",
#     }

#     page = 0
#     passed_start_time = False
#     passed_end_time = False

#     # Get the max 10 pages of reviews for each app if
#     # the reviews are within the time interval
#     # and the reviews are not empty.
#     # If the reviews are empty, break the loop

#     while page < 10 and (not passed_start_time or not passed_end_time):

#         # get the reviews for the app
#         print(f"Getting reviews for app_id: {app_id} page: {page}")
#         reviews_response = get_user_reviews(app_id, params)

#         if not reviews_response or reviews_response.get("success") != 1:
#             print("Request failed or no success response.")
#             break

#         reviews = reviews_response.get("reviews", [])
#         if not reviews:
#             print("Reached the end of the Reviews!!!.")
#             break

#         # While there are still reviews keep extracting them.
#         for review in reviews:
#             timestamp_created = review["timestamp_created"]
#             if timestamp_created > end_time.timestamp():
#                 continue
#             if timestamp_created < start_time.timestamp():
#                 passed_start_time = True
#                 break

#             recommendation_id = review['recommendationid']
#             timestamp_created = review['timestamp_created']
#             timestamp_updated = review['timestamp_updated']
#             # extract the useful (to me) data
#             # Add APP ID to the review 
#             review['app_id'] = app_id
#             author_steamid = review['author']['steamid']        # will automatically redirect to the profileURL if any
#             review_text = review['review']
#             voted_up = review['voted_up']
#             votes_up = review['votes_up']
#             votes_funny = review['votes_funny']
#             weighted_vote_score = review['weighted_vote_score']
#             steam_purchase = review['steam_purchase']
#             received_for_free = review['received_for_free']
#             written_during_early_access = review['written_during_early_access']
            

#             my_review_dict = {
#                 'app_id': app_id,
#                 'recommendationid': recommendation_id,
#                 'author_steamid': author_steamid,

#                 'review_text': review_text,
#                 'timestamp_created': timestamp_created,
#                 'timestamp_updated': timestamp_updated,

#                 'voted_up': voted_up,
#                 'votes_up': votes_up,
#                 'votes_funny': votes_funny,
#                 'weighted_vote_score': weighted_vote_score,
#                 'steam_purchase': steam_purchase,
#                 'received_for_free': received_for_free,
#                 'written_during_early_access': written_during_early_access,
#             }
#             review["app_id"] = app_id
#             selected_reviews.append(review)

#         # Get next page cursor
#         cursor = reviews_response.get("cursor", "")
#         if not cursor:
#             print("Reached the last page!!!")
#             break
        
#         params["cursor"] = cursor
#         print(f"Moving to page {page + 1}. Cursor: {cursor}")
#         page += 1
#         time.sleep(2)

#     time.sleep(2)  # Wait before fetching the next app


# print("Finished processing all app reviews.")

# Process each app ID
for app_id in app_ids:
    print(f"\nGetting reviews for app_id: {app_id}")
    params = {
        "json": 1,
        "language": "turkish",
        "cursor": "*",
        "num_per_page": 100,
        "filter": "recent",
    }

    page = 0
    passed_start_time = False
    passed_end_time = False

    while page < 10 and (not passed_start_time or not passed_end_time):
        print(f"Getting reviews for app_id: {app_id} page: {page}")
        reviews_response = get_user_reviews(app_id, params)

        if not reviews_response or reviews_response.get("success") != 1:
            print("Request failed or no success response.")
            break

        reviews = reviews_response.get("reviews", [])
        if not reviews:
            print("Reached the end of the Reviews!!!.")
            break

        for review in reviews:
            timestamp_created = review["timestamp_created"]
            if timestamp_created > end_time.timestamp():
                continue
            if timestamp_created < start_time.timestamp():
                passed_start_time = True
                break

            # Extract and format the review data
            my_review_dict = {
                'app_id': app_id,
                'recommendationid': review['recommendationid'],
                'author_steamid': review['author']['steamid'],
                'review_text': review['review'],
                'timestamp_created': review['timestamp_created'],
                'timestamp_updated': review['timestamp_updated'],
                'voted_up': review['voted_up'],
                'votes_up': review['votes_up'],
                'votes_funny': review['votes_funny'],
                'weighted_vote_score': review['weighted_vote_score'],
                'steam_purchase': review['steam_purchase'],
                'received_for_free': review['received_for_free'],
                'written_during_early_access': review['written_during_early_access'],
            }
            selected_reviews.append(my_review_dict)

        # Get next page cursor
        cursor = reviews_response.get("cursor", "")
        if not cursor:
            print("Reached the last page!!!")
            break

        params["cursor"] = cursor
        print(f"Moving to page {page + 1}. Cursor: {cursor}")
        page += 1
        time.sleep(2)

    time.sleep(2)  # Wait before fetching the next app

# Save the reviews to a CSV file
if selected_reviews:
    reviews_df = pd.DataFrame(selected_reviews)
    csv_filename = f"reviews_{start_time.strftime('%Y%m%d-%H%M%S')}_{end_time.strftime('%Y%m%d-%H%M%S')}.csv"
    reviews_df.to_csv(csv_filename, index=False, encoding='utf-8')
    print(f"Reviews saved to {csv_filename}")
else:
    print("No reviews were collected.")

print("Finished processing all app reviews.")
# Out:
# Start time: 2024-01-01 00:00:00
# End time: 2025-04-04 16:00:16.856347
# 1704056400.0 1743771616.856347
#
# Getting reviews for app_id: 1245620
# Getting reviews for app_id: 1245620 page: 0
# Moving to page 1. Cursor: AoJwx8ut4ZUDeOXC2AU=
# Getting reviews for app_id: 1245620 page: 1
# Moving to page 2. Cursor: AoJwnoL4zZUDd8f51QU=
# Getting reviews for app_id: 1245620 page: 2
# Moving to page 3. Cursor: AoJw+aSvopUDfseq0AU=
# Getting reviews for app_id: 1245620 page: 3
# Moving to page 4. Cursor: AoJw+oLR+pQDev+CzAU=
# Getting reviews for app_id: 1245620 page: 4
# Moving to page 5. Cursor: AoJ4zeb21JQDfMPYxwU=
# Getting reviews for app_id: 1245620 page: 5
# Moving to page 6. Cursor: AoJ4pKPLvZQDdYiOxQU=
# Getting reviews for app_id: 1245620 page: 6
# Moving to page 7. Cursor: AoJwmP2nppQDc/a/wgU=
# Getting reviews for app_id: 1245620 page: 7
# Moving to page 8. Cursor: AoJ49deFlJQDepiAwAU=
# Getting reviews for app_id: 1245620 page: 8
# Moving to page 9. Cursor: AoJwhJ/6g5QDe8WzvQU=
# Getting reviews for app_id: 1245620 page: 9
# Moving to page 10. Cursor: AoJwt9Sr3pMDc7zGuAU=
#
# Getting reviews for app_id: 3098470
# Getting reviews for app_id: 3098470 page: 0
# Moving to page 1. Cursor: AoJ41+Pw+5QDeJeVzAU=
# Getting reviews for app_id: 3098470 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3089130
# Getting reviews for app_id: 3089130 page: 0
# Moving to page 1. Cursor: AoJw34HUlJEDeYTAjgU=
# Getting reviews for app_id: 3089130 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3087650
# Getting reviews for app_id: 3087650 page: 0
# Moving to page 1. Cursor: AoJwwoeH25MDet+VuAU=
# Getting reviews for app_id: 3087650 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3086060
# Getting reviews for app_id: 3086060 page: 0
# Moving to page 1. Cursor: AoJwq52++pMDffCBvAU=
# Getting reviews for app_id: 3086060 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3074050
# Getting reviews for app_id: 3074050 page: 0
# Moving to page 1. Cursor: AoJ45uz+5ZADeJi9iQU=
# Getting reviews for app_id: 3074050 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3070520
# Getting reviews for app_id: 3070520 page: 0
# Moving to page 1. Cursor: AoJw7Meu75MDfc+/ugU=
# Getting reviews for app_id: 3070520 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3070070
# Getting reviews for app_id: 3070070 page: 0
# Moving to page 1. Cursor: AoJ477+pg5IDc43JnAU=
# Getting reviews for app_id: 3070070 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3069470
# Getting reviews for app_id: 3069470 page: 0
# Moving to page 1. Cursor: AoJ4zbjH2ZADcrmGiAU=
# Getting reviews for app_id: 3069470 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3062990
# Getting reviews for app_id: 3062990 page: 0
# Moving to page 1. Cursor: AoJwr7nx75MDepLIugU=
# Getting reviews for app_id: 3062990 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3061810
# Getting reviews for app_id: 3061810 page: 0
# Moving to page 1. Cursor: AoJwsbiNkpUDd+2+zgU=
# Getting reviews for app_id: 3061810 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3061070
# Getting reviews for app_id: 3061070 page: 0
# Moving to page 1. Cursor: AoJws9CWg5UDeufqzAU=
# Getting reviews for app_id: 3061070 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3059010
# Getting reviews for app_id: 3059010 page: 0
# Moving to page 1. Cursor: AoJ4hszA35IDd8PVpQU=
# Getting reviews for app_id: 3059010 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3058630
# Getting reviews for app_id: 3058630 page: 0
# Moving to page 1. Cursor: AoJ4yYr3uZQDe9TVxAU=
# Getting reviews for app_id: 3058630 page: 1
# Moving to page 2. Cursor: AoJ4kKD8t5QDcfS7xAU=
# Getting reviews for app_id: 3058630 page: 2
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3058310
# Getting reviews for app_id: 3058310 page: 0
# Moving to page 1. Cursor: AoJw5qPtg5EDcoXwjAU=
# Getting reviews for app_id: 3058310 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3056420
# Getting reviews for app_id: 3056420 page: 0
# Moving to page 1. Cursor: AoJw4pWT1JADcq2whwU=
# Getting reviews for app_id: 3056420 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3056580
# Getting reviews for app_id: 3056580 page: 0
# Moving to page 1. Cursor: AoJ4j5mVwJUDduam1AU=
# Getting reviews for app_id: 3056580 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3046980
# Getting reviews for app_id: 3046980 page: 0
# Moving to page 1. Cursor: AoJ4j/752pADf5iXiAU=
# Getting reviews for app_id: 3046980 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3044520
# Getting reviews for app_id: 3044520 page: 0
# Moving to page 1. Cursor: AoJw0vrkp5QDeOvTwgU=
# Getting reviews for app_id: 3044520 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3043530
# Getting reviews for app_id: 3043530 page: 0
# Moving to page 1. Cursor: AoJwubT3tJIDfYfXoQU=
# Getting reviews for app_id: 3043530 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3042220
# Getting reviews for app_id: 3042220 page: 0
# Moving to page 1. Cursor: AoJw+7eik5MDdY7TqgU=
# Getting reviews for app_id: 3042220 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3037780
# Getting reviews for app_id: 3037780 page: 0
# Moving to page 1. Cursor: AoJw04HR0JADdvPyhgU=
# Getting reviews for app_id: 3037780 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3036080
# Getting reviews for app_id: 3036080 page: 0
# Moving to page 1. Cursor: AoJ4qdvtopQDeZ+MwgU=
# Getting reviews for app_id: 3036080 page: 1
# Moving to page 2. Cursor: AoJ47a+uwZMDft3bswU=
# Getting reviews for app_id: 3036080 page: 2
# Moving to page 3. Cursor: AoJwz+Ocm5MDeru/qwU=
# Getting reviews for app_id: 3036080 page: 3
# Moving to page 4. Cursor: AoJw6/vKs5EDevjakQU=
# Getting reviews for app_id: 3036080 page: 4
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3034940
# Getting reviews for app_id: 3034940 page: 0
# Moving to page 1. Cursor: AoJw44/U4ZEDc5PwmAU=
# Getting reviews for app_id: 3034940 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3034950
# Getting reviews for app_id: 3034950 page: 0
# Moving to page 1. Cursor: AoJwg+eFg5IDcojFnAU=
# Getting reviews for app_id: 3034950 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3035040
# Getting reviews for app_id: 3035040 page: 0
# Moving to page 1. Cursor: AoJ49KOAupADfNzxgwU=
# Getting reviews for app_id: 3035040 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3033820
# Getting reviews for app_id: 3033820 page: 0
# Moving to page 1. Cursor: AoJ4ksDP05ADeoGmhwU=
# Getting reviews for app_id: 3033820 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3034130
# Getting reviews for app_id: 3034130 page: 0
# Moving to page 1. Cursor: AoJwrrKU1JEDc6arlwU=
# Getting reviews for app_id: 3034130 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3033500
# Getting reviews for app_id: 3033500 page: 0
# Moving to page 1. Cursor: AoJ4/KnqxJADfY6thQU=
# Getting reviews for app_id: 3033500 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3027930
# Getting reviews for app_id: 3027930 page: 0
# Moving to page 1. Cursor: AoJ4rNa085IDeN7KpwU=
# Getting reviews for app_id: 3027930 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3026100
# Getting reviews for app_id: 3026100 page: 0
# Moving to page 1. Cursor: AoJ4u6Pt9pEDdaeXmwU=
# Getting reviews for app_id: 3026100 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3024580
# Getting reviews for app_id: 3024580 page: 0
# Moving to page 1. Cursor: AoJw/NyS3pADcaLEiAU=
# Getting reviews for app_id: 3024580 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3016840
# Getting reviews for app_id: 3016840 page: 0
# Moving to page 1. Cursor: AoJ4n/mv5ZMDe7WzuQU=
# Getting reviews for app_id: 3016840 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3015760
# Getting reviews for app_id: 3015760 page: 0
# Moving to page 1. Cursor: AoJwtbLh8JADd4ndigU=
# Getting reviews for app_id: 3015760 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3014600
# Getting reviews for app_id: 3014600 page: 0
# Moving to page 1. Cursor: AoJw14Oe3JADc5KriAU=
# Getting reviews for app_id: 3014600 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3011440
# Getting reviews for app_id: 3011440 page: 0
# Moving to page 1. Cursor: AoJwn5b8tZEDf933kQU=
# Getting reviews for app_id: 3011440 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3010450
# Getting reviews for app_id: 3010450 page: 0
# Moving to page 1. Cursor: AoJwiYj0mJADd9Hi/wQ=
# Getting reviews for app_id: 3010450 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3009850
# Getting reviews for app_id: 3009850 page: 0
# Moving to page 1. Cursor: AoJ46eqN7JEDcIiPmgU=
# Getting reviews for app_id: 3009850 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3008670
# Getting reviews for app_id: 3008670 page: 0
# Moving to page 1. Cursor: AoJ49cb63pQDdqTiyAU=
# Getting reviews for app_id: 3008670 page: 1
# Moving to page 2. Cursor: AoJwnLSM3JQDddm2yAU=
# Getting reviews for app_id: 3008670 page: 2
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3006630
# Getting reviews for app_id: 3006630 page: 0
# Moving to page 1. Cursor: AoJ4jZKdkZADf+uC/wQ=
# Getting reviews for app_id: 3006630 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3001560
# Getting reviews for app_id: 3001560 page: 0
# Moving to page 1. Cursor: AoJwz/fOlpMDf835qgU=
# Getting reviews for app_id: 3001560 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2999990
# Getting reviews for app_id: 2999990 page: 0
# Moving to page 1. Cursor: AoJ4kPbMgZEDd6fSjAU=
# Getting reviews for app_id: 2999990 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2999090
# Getting reviews for app_id: 2999090 page: 0
# Moving to page 1. Cursor: AoJw9aiYvZADdNuuhAU=
# Getting reviews for app_id: 2999090 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3349410
# Getting reviews for app_id: 3349410 page: 0
# Moving to page 1. Cursor: AoJ4u5aEz5MDesbLtgU=
# Getting reviews for app_id: 3349410 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3349420
# Getting reviews for app_id: 3349420 page: 0
# Moving to page 1. Cursor: AoJ46Z/Q2JMDeLLytwU=
# Getting reviews for app_id: 3349420 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3349430
# Getting reviews for app_id: 3349430 page: 0
# Moving to page 1. Cursor: AoJwppO10JMDcKLktgU=
# Getting reviews for app_id: 3349430 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3345580
# Getting reviews for app_id: 3345580 page: 0
# Moving to page 1. Cursor: AoJ4kZnp9JMDd86YuwU=
# Getting reviews for app_id: 3345580 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3342630
# Getting reviews for app_id: 3342630 page: 0
# Moving to page 1. Cursor: AoJ4//+dy5MDe8GItgU=
# Getting reviews for app_id: 3342630 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3340810
# Getting reviews for app_id: 3340810 page: 0
# Moving to page 1. Cursor: AoJw0I/NuZMDeYawsAU=
# Getting reviews for app_id: 3340810 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3335300
# Getting reviews for app_id: 3335300 page: 0
# Moving to page 1. Cursor: AoJw7rTU5pQDesrbyQU=
# Getting reviews for app_id: 3335300 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3331000
# Getting reviews for app_id: 3331000 page: 0
# Moving to page 1. Cursor: AoJwnfyH1JMDfr2wtwU=
# Getting reviews for app_id: 3331000 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3326290
# Getting reviews for app_id: 3326290 page: 0
# Moving to page 1. Cursor: AoJwjYr2sJQDcaTkwwU=
# Getting reviews for app_id: 3326290 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3323350
# Getting reviews for app_id: 3323350 page: 0
# Moving to page 1. Cursor: AoJ48bXz6pMDf5T/uQU=
# Getting reviews for app_id: 3323350 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3323360
# Getting reviews for app_id: 3323360 page: 0
# Moving to page 1. Cursor: AoJwjZjz6pMDfpD/uQU=
# Getting reviews for app_id: 3323360 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3318000
# Getting reviews for app_id: 3318000 page: 0
# Moving to page 1. Cursor: AoJ44qSalZUDefzszgU=
# Getting reviews for app_id: 3318000 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3311740
# Getting reviews for app_id: 3311740 page: 0
# Moving to page 1. Cursor: AoJ4jNW565MDdNOHugU=
# Getting reviews for app_id: 3311740 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3301410
# Getting reviews for app_id: 3301410 page: 0
# Moving to page 1. Cursor: AoJ4hqfZuZQDe5jTxAU=
# Getting reviews for app_id: 3301410 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3292260
# Getting reviews for app_id: 3292260 page: 0
# Moving to page 1. Cursor: AoJ41anao5QDca2cwgU=
# Getting reviews for app_id: 3292260 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3287520
# Getting reviews for app_id: 3287520 page: 0
# Moving to page 1. Cursor: AoJ4xLPP55QDdqHoyQU=
# Getting reviews for app_id: 3287520 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3279160
# Getting reviews for app_id: 3279160 page: 0
# Moving to page 1. Cursor: AoJ405zxtJQDfbGUxAU=
# Getting reviews for app_id: 3279160 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3272290
# Getting reviews for app_id: 3272290 page: 0
# Moving to page 1. Cursor: AoJwhdPuyJIDeODSowU=
# Getting reviews for app_id: 3272290 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3265330
# Getting reviews for app_id: 3265330 page: 0
# Moving to page 1. Cursor: AoJw89y6xZQDcp78xQU=
# Getting reviews for app_id: 3265330 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3264050
# Getting reviews for app_id: 3264050 page: 0
# Moving to page 1. Cursor: AoJwyLnP1pQDd+nrxwU=
# Getting reviews for app_id: 3264050 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3263320
# Getting reviews for app_id: 3263320 page: 0
# Moving to page 1. Cursor: AoJ47OSn0JMDeqvitgU=
# Getting reviews for app_id: 3263320 page: 1
# Moving to page 2. Cursor: AoJwqsDH35IDcrHWpQU=
# Getting reviews for app_id: 3263320 page: 2
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3261720
# Getting reviews for app_id: 3261720 page: 0
# Moving to page 1. Cursor: AoJ4otPsuZMDfanMsAU=
# Getting reviews for app_id: 3261720 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 3469800
# Getting reviews for app_id: 3469800 page: 0
# Moving to page 1. Cursor: AoJwmo+Sn5UDfdz/zwU=
# Getting reviews for app_id: 3469800 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2620730
# Getting reviews for app_id: 2620730 page: 0
# Moving to page 1. Cursor: AoJwj+6HkpEDfLCfjgU=
# Getting reviews for app_id: 2620730 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2616420
# Getting reviews for app_id: 2616420 page: 0
# Moving to page 1. Cursor: AoJ4gpfVyI0Dd9bO2gQ=
# Getting reviews for app_id: 2616420 page: 1
# Moving to page 2. Cursor: AoJ49MKhgIwDfuD3wQQ=
# Getting reviews for app_id: 2616420 page: 2
# Moving to page 3. Cursor: AoJw/aug94sDdqSUvgQ=
# Getting reviews for app_id: 2616420 page: 3
# Moving to page 4. Cursor: AoJw28Gf34sDdPv4uwQ=
# Getting reviews for app_id: 2616420 page: 4
# Moving to page 5. Cursor: AoJ4+f311IsDePeIuwQ=
# Getting reviews for app_id: 2616420 page: 5
# Moving to page 6. Cursor: AoJw9tLn0osDeKb0ugQ=
# Getting reviews for app_id: 2616420 page: 6
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2616460
# Getting reviews for app_id: 2616460 page: 0
# Moving to page 1. Cursor: AoJw36LDn44Dc6G25AQ=
# Getting reviews for app_id: 2616460 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2614920
# Getting reviews for app_id: 2614920 page: 0
# Moving to page 1. Cursor: AoJ4yJeyjYsDcP3DtAQ=
# Getting reviews for app_id: 2614920 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2613400
# Getting reviews for app_id: 2613400 page: 0
# Moving to page 1. Cursor: AoJ49anp5ZADcZi6iQU=
# Getting reviews for app_id: 2613400 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2611740
# Getting reviews for app_id: 2611740 page: 0
# Moving to page 1. Cursor: AoJ45MHG+YsDfKeuvgQ=
# Getting reviews for app_id: 2611740 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2608620
# Getting reviews for app_id: 2608620 page: 0
# Moving to page 1. Cursor: AoJwu4Lf3Y8Ddsz1+QQ=
# Getting reviews for app_id: 2608620 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2608270
# Getting reviews for app_id: 2608270 page: 0
# Moving to page 1. Cursor: AoJ45JOwrpEDfaCUkQU=
# Getting reviews for app_id: 2608270 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2607620
# Getting reviews for app_id: 2607620 page: 0
# Moving to page 1. Cursor: AoJ48Ki7gosDe+DIswQ=
# Getting reviews for app_id: 2607620 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2606920
# Getting reviews for app_id: 2606920 page: 0
# Moving to page 1. Cursor: AoJ4iezdsY8Df6Tb9QQ=
# Getting reviews for app_id: 2606920 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2604420
# Getting reviews for app_id: 2604420 page: 0
# Moving to page 1. Cursor: AoJw1rSNypMDe5T7tQU=
# Getting reviews for app_id: 2604420 page: 1
# Moving to page 2. Cursor: AoJ48aG2yZMDebbwtQU=
# Getting reviews for app_id: 2604420 page: 2
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2601580
# Getting reviews for app_id: 2601580 page: 0
# Moving to page 1. Cursor: AoJwh+nN4JMDer/muAU=
# Getting reviews for app_id: 2601580 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2599300
# Getting reviews for app_id: 2599300 page: 0
# Moving to page 1. Cursor: AoJwvp35+YsDfoL1vgQ=
# Getting reviews for app_id: 2599300 page: 1
# Moving to page 2. Cursor: AoJw+riSp4sDdfnYtgQ=
# Getting reviews for app_id: 2599300 page: 2
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2598930
# Getting reviews for app_id: 2598930 page: 0
# Moving to page 1. Cursor: AoJwt/ub94sDdeqTvgQ=
# Getting reviews for app_id: 2598930 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2597970
# Getting reviews for app_id: 2597970 page: 0
# Moving to page 1. Cursor: AoJ4w/SG55IDdpy4pgU=
# Getting reviews for app_id: 2597970 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2598020
# Getting reviews for app_id: 2598020 page: 0
# Moving to page 1. Cursor: AoJwy5yg0JMDdqThtgU=
# Getting reviews for app_id: 2598020 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2596100
# Getting reviews for app_id: 2596100 page: 0
# Moving to page 1. Cursor: AoJ4zcPTxIwDfa/HywQ=
# Getting reviews for app_id: 2596100 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2594540
# Getting reviews for app_id: 2594540 page: 0
# Moving to page 1. Cursor: AoJ42rOS8ZEDdqvOmgU=
# Getting reviews for app_id: 2594540 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2593420
# Getting reviews for app_id: 2593420 page: 0
# Moving to page 1. Cursor: AoJwgdTP7IsDcL2MvQQ=
# Getting reviews for app_id: 2593420 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2591240
# Getting reviews for app_id: 2591240 page: 0
# Moving to page 1. Cursor: AoJwoP/o54sDerLcvAQ=
# Getting reviews for app_id: 2591240 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2591280
# Getting reviews for app_id: 2591280 page: 0
# Moving to page 1. Cursor: AoJwzYKb8JADdfXTigU=
# Getting reviews for app_id: 2591280 page: 1
# Moving to page 2. Cursor: AoJw7rCI8JADcI7RigU=
# Getting reviews for app_id: 2591280 page: 2
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2587770
# Getting reviews for app_id: 2587770 page: 0
# Moving to page 1. Cursor: AoJ4+96Tyo4DduDA6QQ=
# Getting reviews for app_id: 2587770 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2585150
# Getting reviews for app_id: 2585150 page: 0
# Moving to page 1. Cursor: AoJ45/HB/5EDdd6UnAU=
# Getting reviews for app_id: 2585150 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2584650
# Getting reviews for app_id: 2584650 page: 0
# Moving to page 1. Cursor: AoJwzpWf3Y8DfLPu+QQ=
# Getting reviews for app_id: 2584650 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2582360
# Getting reviews for app_id: 2582360 page: 0
# Moving to page 1. Cursor: AoJ479q52o4DdZCt6wQ=
# Getting reviews for app_id: 2582360 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2581740
# Getting reviews for app_id: 2581740 page: 0
# Moving to page 1. Cursor: AoJ448KvpIsDfZe7tgQ=
# Getting reviews for app_id: 2581740 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2580020
# Getting reviews for app_id: 2580020 page: 0
# Moving to page 1. Cursor: AoJ4jeLYo5MDeaWvrAU=
# Getting reviews for app_id: 2580020 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2579670
# Getting reviews for app_id: 2579670 page: 0
# Moving to page 1. Cursor: AoJwgt3IwooDeIW2rQQ=
# Getting reviews for app_id: 2579670 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2578880
# Getting reviews for app_id: 2578880 page: 0
# Moving to page 1. Cursor: AoJw68GCko8De6PZ8AQ=
# Getting reviews for app_id: 2578880 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2578910
# Getting reviews for app_id: 2578910 page: 0
# Moving to page 1. Cursor: AoJ42fj69ZEDd8qJmwU=
# Getting reviews for app_id: 2578910 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2576550
# Getting reviews for app_id: 2576550 page: 0
# Moving to page 1. Cursor: AoJwgJOPrIsDdfOWtwQ=
# Getting reviews for app_id: 2576550 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2576780
# Getting reviews for app_id: 2576780 page: 0
# Moving to page 1. Cursor: AoJ43Zqq14oDcvifrwQ=
# Getting reviews for app_id: 2576780 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2576040
# Getting reviews for app_id: 2576040 page: 0
# Moving to page 1. Cursor: AoJ475aVsJADe5XCggU=
# Getting reviews for app_id: 2576040 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2574840
# Getting reviews for app_id: 2574840 page: 0
# Moving to page 1. Cursor: AoJ47db/h44DeamH4gQ=
# Getting reviews for app_id: 2574840 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2570950
# Getting reviews for app_id: 2570950 page: 0
# Moving to page 1. Cursor: AoJwvuC8+4oDfPT9sgQ=
# Getting reviews for app_id: 2570950 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2570210
# Getting reviews for app_id: 2570210 page: 0
# Moving to page 1. Cursor: AoJ4laiwzJIDfcX3owU=
# Getting reviews for app_id: 2570210 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2569750
# Getting reviews for app_id: 2569750 page: 0
# Moving to page 1. Cursor: AoJ4w4ajx4sDdtveuQQ=
# Getting reviews for app_id: 2569750 page: 1
# Moving to page 2. Cursor: AoJ4x/qAwYsDffyYuQQ=
# Getting reviews for app_id: 2569750 page: 2
# Moving to page 3. Cursor: AoJwqPnvwIsDe5GXuQQ=
# Getting reviews for app_id: 2569750 page: 3
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2567490
# Getting reviews for app_id: 2567490 page: 0
# Moving to page 1. Cursor: AoJw6dPEuYsDeo61uAQ=
# Getting reviews for app_id: 2567490 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2567870
# Getting reviews for app_id: 2567870 page: 0
# Moving to page 1. Cursor: AoJwlc+fnZUDcpnnzwU=
# Getting reviews for app_id: 2567870 page: 1
# Moving to page 2. Cursor: AoJ4mJyfv5QDeOKkxQU=
# Getting reviews for app_id: 2567870 page: 2
# Moving to page 3. Cursor: AoJwndD7zpMDcYLKtgU=
# Getting reviews for app_id: 2567870 page: 3
# Moving to page 4. Cursor: AoJ4rs7+wZMDd5b6swU=
# Getting reviews for app_id: 2567870 page: 4
# Moving to page 5. Cursor: AoJ4lPnEvpMDeobOsgU=
# Getting reviews for app_id: 2567870 page: 5
# Moving to page 6. Cursor: AoJ4vc6+upMDeMaAsQU=
# Getting reviews for app_id: 2567870 page: 6
# Moving to page 7. Cursor: AoJ4uKqWuZMDd4yBsAU=
# Getting reviews for app_id: 2567870 page: 7
# Moving to page 8. Cursor: AoJ4toDGt5MDevLVrgU=
# Getting reviews for app_id: 2567870 page: 8
# Moving to page 9. Cursor: AoJw4oPEk5MDdcnWqgU=
# Getting reviews for app_id: 2567870 page: 9
# Moving to page 10. Cursor: AoJ42+Gjp5IDdL+loAU=
#
# Getting reviews for app_id: 2564880
# Getting reviews for app_id: 2564880 page: 0
# Moving to page 1. Cursor: AoJwx96q4ZADfOv3iAU=
# Getting reviews for app_id: 2564880 page: 1
# Moving to page 2. Cursor: AoJ4jMmVt40Df6zd2AQ=
# Getting reviews for app_id: 2564880 page: 2
# Moving to page 3. Cursor: AoJw3dCLq40DdLm01wQ=
# Getting reviews for app_id: 2564880 page: 3
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2562240
# Getting reviews for app_id: 2562240 page: 0
# Moving to page 1. Cursor: AoJ4mI3K+ooDdZLxsgQ=
# Getting reviews for app_id: 2562240 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2561580
# Getting reviews for app_id: 2561580 page: 0
# Moving to page 1. Cursor: AoJ40eTN8ZIDeoW1pwU=
# Getting reviews for app_id: 2561580 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2561220
# Getting reviews for app_id: 2561220 page: 0
# Moving to page 1. Cursor: AoJ485Hz1ooDdcmZrwQ=
# Getting reviews for app_id: 2561220 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2560520
# Getting reviews for app_id: 2560520 page: 0
# Moving to page 1. Cursor: AoJwhsL4zIoDcvuirgQ=
# Getting reviews for app_id: 2560520 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2560640
# Getting reviews for app_id: 2560640 page: 0
# Moving to page 1. Cursor: AoJ4j/SwwIoDfYGgrQQ=
# Getting reviews for app_id: 2560640 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2560650
# Getting reviews for app_id: 2560650 page: 0
# Moving to page 1. Cursor: AoJ4tqKU0YoDf6DYrgQ=
# Getting reviews for app_id: 2560650 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2559270
# Getting reviews for app_id: 2559270 page: 0
# Moving to page 1. Cursor: AoJw2ffZt5MDeK3xrgU=
# Getting reviews for app_id: 2559270 page: 1
# Moving to page 2. Cursor: AoJw3Nyqm5ADc6CBgAU=
# Getting reviews for app_id: 2559270 page: 2
# Moving to page 3. Cursor: AoJwg4Sruo0DecOQ2QQ=
# Getting reviews for app_id: 2559270 page: 3
# Moving to page 4. Cursor: AoJ41tD+powDe5WyyAQ=
# Getting reviews for app_id: 2559270 page: 4
# Moving to page 5. Cursor: AoJ4rPDngowDcfD5wgQ=
# Getting reviews for app_id: 2559270 page: 5
# Moving to page 6. Cursor: AoJ4jd7M94sDcp6YvgQ=
# Getting reviews for app_id: 2559270 page: 6
# Moving to page 7. Cursor: AoJ4hZmP5YsDeLzAvAQ=
# Getting reviews for app_id: 2559270 page: 7
# Moving to page 8. Cursor: AoJwmoyw3YsDdpvjuwQ=
# Getting reviews for app_id: 2559270 page: 8
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2558800
# Getting reviews for app_id: 2558800 page: 0
# Moving to page 1. Cursor: AoJ4ir3Eu4oDcLPdrAQ=
# Getting reviews for app_id: 2558800 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2557750
# Getting reviews for app_id: 2557750 page: 0
# Moving to page 1. Cursor: AoJw8N3Lh4sDc7KGtAQ=
# Getting reviews for app_id: 2557750 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2555420
# Getting reviews for app_id: 2555420 page: 0
# Moving to page 1. Cursor: AoJ4lsrHw4sDd5S1uQQ=
# Getting reviews for app_id: 2555420 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2555430
# Getting reviews for app_id: 2555430 page: 0
# Moving to page 1. Cursor: AoJwm+vxt5ADd7/OgwU=
# Getting reviews for app_id: 2555430 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2555190
# Getting reviews for app_id: 2555190 page: 0
# Moving to page 1. Cursor: AoJ459Cj7I4DeMCI7QQ=
# Getting reviews for app_id: 2555190 page: 1
# Moving to page 2. Cursor: AoJw3eGXs40Df72j2AQ=
# Getting reviews for app_id: 2555190 page: 2
# Moving to page 3. Cursor: AoJ4leDUrY0DebLV1wQ=
# Getting reviews for app_id: 2555190 page: 3
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2555320
# Getting reviews for app_id: 2555320 page: 0
# Moving to page 1. Cursor: AoJ4upzs8osDcbrevQQ=
# Getting reviews for app_id: 2555320 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2553870
# Getting reviews for app_id: 2553870 page: 0
# Moving to page 1. Cursor: AoJ4iuOaqYoDeNf5qgQ=
# Getting reviews for app_id: 2553870 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2552680
# Getting reviews for app_id: 2552680 page: 0
# Moving to page 1. Cursor: AoJwkq/S+I4DdpKX7gQ=
# Getting reviews for app_id: 2552680 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2551170
# Getting reviews for app_id: 2551170 page: 0
# Moving to page 1. Cursor: AoJ4k8+k6osDcqz1vAQ=
# Getting reviews for app_id: 2551170 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2339930
# Getting reviews for app_id: 2339930 page: 0
# Moving to page 1. Cursor: AoJwsba3yocDcoqiigQ=
# Getting reviews for app_id: 2339930 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2338770
# Getting reviews for app_id: 2338770 page: 0
# Moving to page 1. Cursor: AoJ44rm77Y8Dfcmv+wQ=
# Getting reviews for app_id: 2338770 page: 1
# Moving to page 2. Cursor: AoJ45fOo1I4Dc9fT6gQ=
# Getting reviews for app_id: 2338770 page: 2
# Moving to page 3. Cursor: AoJ41KC3840Desbs3wQ=
# Getting reviews for app_id: 2338770 page: 3
# Moving to page 4. Cursor: AoJ4uOGz3YsDes/juwQ=
# Getting reviews for app_id: 2338770 page: 4
# Moving to page 5. Cursor: AoJwn+XouooDd8DTrAQ=
# Getting reviews for app_id: 2338770 page: 5
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2337460
# Getting reviews for app_id: 2337460 page: 0
# Moving to page 1. Cursor: AoJwzLjYhJEDee/6jAU=
# Getting reviews for app_id: 2337460 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2336880
# Getting reviews for app_id: 2336880 page: 0
# Moving to page 1. Cursor: AoJwpN2g8o8DfJ7r+wQ=
# Getting reviews for app_id: 2336880 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2336881
# Getting reviews for app_id: 2336881 page: 0
# Moving to page 1. Cursor: AoJ4+tDp9o8Desyk/AQ=
# Getting reviews for app_id: 2336881 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2336200
# Getting reviews for app_id: 2336200 page: 0
# Moving to page 1. Cursor: AoJwovb7i4kDcZK8mgQ=
# Getting reviews for app_id: 2336200 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2335810
# Getting reviews for app_id: 2335810 page: 0
# Moving to page 1. Cursor: AoJwjof1vo4DcJ+k6AQ=
# Getting reviews for app_id: 2335810 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2334730
# Getting reviews for app_id: 2334730 page: 0
# Moving to page 1. Cursor: AoJ4p+jR5I0DeOT83QQ=
# Getting reviews for app_id: 2334730 page: 1
# Moving to page 2. Cursor: AoJw2afJ+YsDcI2zvgQ=
# Getting reviews for app_id: 2334730 page: 2
# Moving to page 3. Cursor: AoJw5rqQ6YsDff7nvAQ=
# Getting reviews for app_id: 2334730 page: 3
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2334210
# Getting reviews for app_id: 2334210 page: 0
# Moving to page 1. Cursor: AoJ4hZOI8YgDdsXzlwQ=
# Getting reviews for app_id: 2334210 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2330970
# Getting reviews for app_id: 2330970 page: 0
# Moving to page 1. Cursor: AoJ4/obvyocDccCnigQ=
# Getting reviews for app_id: 2330970 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2330210
# Getting reviews for app_id: 2330210 page: 0
# Moving to page 1. Cursor: AoJw89r7kIwDfq2RxgQ=
# Getting reviews for app_id: 2330210 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2330500
# Getting reviews for app_id: 2330500 page: 0
# Moving to page 1. Cursor: AoJ42ISajYgDfbLEjwQ=
# Getting reviews for app_id: 2330500 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2328720
# Getting reviews for app_id: 2328720 page: 0
# Moving to page 1. Cursor: AoJ4+OHO2YcDcsC7iwQ=
# Getting reviews for app_id: 2328720 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2328750
# Getting reviews for app_id: 2328750 page: 0
# Moving to page 1. Cursor: AoJ4zLHCgIsDesO1swQ=
# Getting reviews for app_id: 2328750 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2328780
# Getting reviews for app_id: 2328780 page: 0
# Moving to page 1. Cursor: AoJwssqgoIwDeNHUxwQ=
# Getting reviews for app_id: 2328780 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2328980
# Getting reviews for app_id: 2328980 page: 0
# Moving to page 1. Cursor: AoJ4ioOXjokDeOXbmgQ=
# Getting reviews for app_id: 2328980 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2328320
# Getting reviews for app_id: 2328320 page: 0
# Moving to page 1. Cursor: AoJ47rj7h44Dd9uG4gQ=
# Getting reviews for app_id: 2328320 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2325830
# Getting reviews for app_id: 2325830 page: 0
# Moving to page 1. Cursor: AoJ4i7r5pYoDeaXLqgQ=
# Getting reviews for app_id: 2325830 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2325832
# Getting reviews for app_id: 2325832 page: 0
# Moving to page 1. Cursor: AoJ4wa70l48DeoKn8QQ=
# Getting reviews for app_id: 2325832 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2322560
# Getting reviews for app_id: 2322560 page: 0
# Moving to page 1. Cursor: AoJw1PrstosDd/ySuAQ=
# Getting reviews for app_id: 2322560 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2322010
# Getting reviews for app_id: 2322010 page: 0
# Moving to page 1. Cursor: AoJwzdibkpUDc97AzgU=
# Getting reviews for app_id: 2322010 page: 1
# Moving to page 2. Cursor: AoJ4q42dvJQDecr2xAU=
# Getting reviews for app_id: 2322010 page: 2
# Moving to page 3. Cursor: AoJwx+G3/ZMDctayvAU=
# Getting reviews for app_id: 2322010 page: 3
# Moving to page 4. Cursor: AoJ4iszcwJMDddq7swU=
# Getting reviews for app_id: 2322010 page: 4
# Moving to page 5. Cursor: AoJ4/7Hzt5MDdqaMrwU=
# Getting reviews for app_id: 2322010 page: 5
# Moving to page 6. Cursor: AoJw4+XOjpMDd9WhqgU=
# Getting reviews for app_id: 2322010 page: 6
# Moving to page 7. Cursor: AoJ4lpWu2JIDfPeGpQU=
# Getting reviews for app_id: 2322010 page: 7
# Moving to page 8. Cursor: AoJ4/KTjs5IDceHHoQU=
# Getting reviews for app_id: 2322010 page: 8
# Moving to page 9. Cursor: AoJw2MTGoZIDcZndnwU=
# Getting reviews for app_id: 2322010 page: 9
# Moving to page 10. Cursor: AoJ41v+hkpIDcMmXngU=
#
# Getting reviews for app_id: 2321210
# Getting reviews for app_id: 2321210 page: 0
# Moving to page 1. Cursor: AoJw06vJ6YcDdJbijAQ=
# Getting reviews for app_id: 2321210 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2321092
# Getting reviews for app_id: 2321092 page: 0
# Moving to page 1. Cursor: AoJ4h5zA14cDd4eoiwQ=
# Getting reviews for app_id: 2321092 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2321101
# Getting reviews for app_id: 2321101 page: 0
# Moving to page 1. Cursor: AoJw5P6+jY4DdfDM4gQ=
# Getting reviews for app_id: 2321101 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2317960
# Getting reviews for app_id: 2317960 page: 0
# Moving to page 1. Cursor: AoJ4wtOs2ocDepTEiwQ=
# Getting reviews for app_id: 2317960 page: 1
# Reached the end of the Reviews!!!.
#
# Getting reviews for app_id: 2317820
# Getting reviews for app_id: 2317820 page: 0
# Moving to page 1. Cursor: AoJwjeKMs4kDcb3pngQ=
# Getting reviews for app_id: 2317820 page: 1
# Moving to page 2. Cursor: AoJ4ytjKsokDeLringQ=
# Getting reviews for app_id: 2317820 page: 2
# Reached the end of the Reviews!!!.
# Reviews saved to reviews_20240101-000000_20250404-160016.csv
# Finished processing all app reviews.
