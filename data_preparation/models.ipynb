# %% [markdown]
# # Turkish Game Review Sentiment/Topic Classification: Model Training Pipeline
#
# This notebook demonstrates the full workflow for training and evaluating two NLP models (Logistic Regression and BERTurk) on Turkish game review data.

# %% [markdown]
# ## 1. Install & Import Required Libraries
#
# Install dependencies (if running in a new environment) and import all necessary libraries.

# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: pandas in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 2)) (2.2.2)
# Requirement already satisfied: numpy in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 3)) (1.26.4)
# Requirement already satisfied: zemberek-python in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 6)) (0.2.3)
# Requirement already satisfied: regex in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 7)) (2024.5.15)
# Requirement already satisfied: nltk in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 10)) (3.9.1)
# Requirement already satisfied: scikit-learn in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 16)) (1.5.1)
# Requirement already satisfied: joblib in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 17)) (1.4.2)
# Requirement already satisfied: transformers in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 20)) (4.45.1)
# Requirement already satisfied: datasets in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 21)) (3.6.0)
# Requirement already satisfied: torch in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 24)) (2.7.0)
# Requirement already satisfied: torchaudio in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 25)) (2.7.0)
# Requirement already satisfied: torchvision in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 26)) (0.22.0)
# Requirement already satisfied: tqdm in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 29)) (4.66.4)
# Requirement already satisfied: fastapi in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 32)) (0.115.12)
# Requirement already satisfied: uvicorn in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 33)) (0.34.1)
# Requirement already satisfied: matplotlib in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 36)) (3.9.1)
# Requirement already satisfied: seaborn in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 37)) (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\almud\appdata\roaming\python\python310\site-packages (from pandas->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: antlr4-python3-runtime==4.8 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from zemberek-python->-r requirements.txt (line 6)) (4.8)
# Requirement already satisfied: click in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from nltk->-r requirements.txt (line 10)) (8.1.8)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->-r requirements.txt (line 16)) (1.14.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->-r requirements.txt (line 16)) (3.5.0)
# Requirement already satisfied: filelock in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from transformers->-r requirements.txt (line 20)) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from transformers->-r requirements.txt (line 20)) (0.24.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from transformers->-r requirements.txt (line 20)) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from transformers->-r requirements.txt (line 20)) (6.0.2)
# Requirement already satisfied: requests in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from transformers->-r requirements.txt (line 20)) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from transformers->-r requirements.txt (line 20)) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from transformers->-r requirements.txt (line 20)) (0.20.0)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from datasets->-r requirements.txt (line 21)) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from datasets->-r requirements.txt (line 21)) (0.3.8)
# Requirement already satisfied: xxhash in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from datasets->-r requirements.txt (line 21)) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from datasets->-r requirements.txt (line 21)) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r requirements.txt (line 21)) (2024.6.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from torch->-r requirements.txt (line 24)) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from torch->-r requirements.txt (line 24)) (1.14.0)
# Requirement already satisfied: networkx in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from torch->-r requirements.txt (line 24)) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from torch->-r requirements.txt (line 24)) (3.1.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from torchvision->-r requirements.txt (line 26)) (10.4.0)
# Requirement already satisfied: colorama in c:\users\almud\appdata\roaming\python\python310\site-packages (from tqdm->-r requirements.txt (line 29)) (0.4.6)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from fastapi->-r requirements.txt (line 32)) (0.46.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from fastapi->-r requirements.txt (line 32)) (2.10.3)
# Requirement already satisfied: h11>=0.8 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from uvicorn->-r requirements.txt (line 33)) (0.14.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->-r requirements.txt (line 36)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->-r requirements.txt (line 36)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->-r requirements.txt (line 36)) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->-r requirements.txt (line 36)) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->-r requirements.txt (line 36)) (3.1.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r requirements.txt (line 21)) (3.9.5)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi->-r requirements.txt (line 32)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi->-r requirements.txt (line 32)) (2.27.1)
# Requirement already satisfied: six>=1.5 in c:\users\almud\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from requests->transformers->-r requirements.txt (line 20)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from requests->transformers->-r requirements.txt (line 20)) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from requests->transformers->-r requirements.txt (line 20)) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from requests->transformers->-r requirements.txt (line 20)) (2024.2.2)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from starlette<0.47.0,>=0.40.0->fastapi->-r requirements.txt (line 32)) (4.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from sympy>=1.13.3->torch->-r requirements.txt (line 24)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from jinja2->torch->-r requirements.txt (line 24)) (2.1.5)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r requirements.txt (line 21)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r requirements.txt (line 21)) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r requirements.txt (line 21)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r requirements.txt (line 21)) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r requirements.txt (line 21)) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r requirements.txt (line 21)) (4.0.3)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\almud\appdata\roaming\python\python310\site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi->-r requirements.txt (line 32)) (1.2.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\almud\appdata\local\programs\python\python310\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi->-r requirements.txt (line 32)) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import re
import string
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns

# For BERT
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification, Trainer, TrainingArguments
from datasets import Dataset, load_metric
# ZEMBEREK PYTHON FOR LEMMATIZATION
from zemberek import (
    TurkishMorphology,
    TurkishSentenceNormalizer,
    TurkishSpellChecker,
    TurkishTokenizer
)


# Additional imports for constants
import json

# %% [markdown]
# # 2. Data Processing

# %%
def read_excel_file(file_path):
    """
    Reads an Excel file and returns a DataFrame.
    """
    try:
        df = pd.read_excel(file_path)
        print(f"Successfully read the file: {file_path}")
        return df
    except Exception as e:
        print(f"Error reading the file: {file_path}. Error: {e}")
        return None

# %%
# path:

FILE_PATH = "dataset/cleaned_reviews_zemberek.xlsx"

# %%
df = read_excel_file(FILE_PATH)

# print the first few rows of the DataFrame
df.head(5)
# Out:
# Successfully read the file: dataset/cleaned_reviews_zemberek.xlsx
#    review_id   app_id                                        review_text  \
# 0          1  1245620  İlk 40 saatimde nereye gitmem gerektiğini ne y...
# 1          2  1245620  Bu oyunda Malenia bossunu tasarlıyan arkadaşa ...
# 2          3  1245620  Güzel oyun  atmosfer kontroller vs. güzel ama ...
# 3          4  1245620  Oyunun devasa bir haritası var açık dünya olma...
# 4          5  1245620       oynu bitirdiğinizde huzurluca ölebilirisiniz
#
#    Grafik      AI  Oynanis Ses ve Muzik Oyun Dunyasi Topluluk ve Sosyal  \
# 0    Nötr    Nötr  Olumsuz         Nötr         Nötr               Nötr
# 1    Nötr    Nötr   Olumlu         Nötr         Nötr               Nötr
# 2  Olumlu    Nötr   Olumlu         Nötr       Olumlu               Nötr
# 3    Nötr  Olumlu   Olumlu         Nötr       Olumlu               Nötr
# 4    Nötr    Nötr     Nötr         Nötr         Nötr               Nötr
#
#   Hikaye ve Senaryo Performans ve Teknik Genel Duygu
# 0              Nötr                 Nötr        Nötr
# 1              Nötr                 Nötr        Nötr
# 2              Nötr                 Nötr        Nötr
# 3              Nötr                 Nötr        Nötr
# 4              Nötr                 Nötr        Nötr

# %%
def normalize_text(text):
    """
    Normalize the text by removing punctuation, converting to lowercase, and removing extra spaces.
    """
    text = text.lower()
    text = re.sub(f"[{re.escape(string.punctuation)}]", " ", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

def replace_turkish_characters(text):
    """
    Replace Turkish characters with their English equivalents.
    """
    replacements = {
        'ç': 'c', 'ğ': 'g', 'ı': 'i', 'ö': 'o', 'ş': 's', 'ü': 'u',
        'Ç': 'C', 'Ğ': 'G', 'İ': 'I', 'Ö': 'O', 'Ş': 'S', 'Ü': 'U'
    }
    for turkish_char, english_char in replacements.items():
        text = text.replace(turkish_char, english_char)
    return text

# Lemmatize the text using Zemberek
from zemberek.morphology import TurkishMorphology
from zemberek.tokenization import TurkishTokenizer
from zemberek.normalization import TurkishSentenceNormalizer

def lemmatize_text(text):
    """
    Lemmatize the text using Zemberek.
    """
    morphology = TurkishMorphology.create_with_defaults()
    normalizer = TurkishSentenceNormalizer(morphology)

    # Normalize the text
    normalized_text = normalizer.normalize(text)

    # Tokenize and lemmatize
    tokenizer = TurkishTokenizer.DEFAULT
    tokens = tokenizer.tokenize(normalized_text)

    lemmatized_tokens = [morphology.analyze(token).best_analysis().lemma for token in tokens]

    return ' '.join(lemmatized_tokens)

# Example usage:
print(lemmatize_text("Bu bir örnek cümledir."))


def preprocess_text(text):
    """
    Preprocess the text by normalizing and replacing Turkish characters.
    """
    text = normalize_text(text)
    text = replace_turkish_characters(text)
    return text
